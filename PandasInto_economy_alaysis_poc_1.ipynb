# %% [markdown]
# <a href="https://colab.research.google.com/github/RKumarAccount/Pandas-DataFrame/blob/main/PandasInto_economy_alaysis_poc_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel('/content/data.xlsx')

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
id(df)
# Out:
# 133080871330032

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
len(df)
# Out:
# 195

# %%
df.shape #dimension of data frame
# Out:
# (195, 5)

# %%
df.head() # top 5 rows
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.head(2) #top 2 rows
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0        Aruba         ABW     10.244           78.9  High income
# 1  Afghanistan         AFG     35.253            5.9   Low income

# %%
df.tail() #bottom 5 rows
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.info() #info of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 5

# %%
df.dtypes
# Out:
# CountryName       object
# CountryCode       object
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup       object
# dtype: object

# %%
df.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df['CountryName']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
df['CountryCode']
# Out:
# 0      ABW
# 1      AFG
# 2      AGO
# 3      ALB
# 4      ARE
#       ...
# 190    YEM
# 191    ZAF
# 192    COD
# 193    ZMB
# 194    ZWE
# Name: CountryCode, Length: 195, dtype: object

# %%
df[['CountryCode','CountryName']]
# Out:
#     CountryCode           CountryName
# 0           ABW                 Aruba
# 1           AFG           Afghanistan
# 2           AGO                Angola
# 3           ALB               Albania
# 4           ARE  United Arab Emirates
# ..          ...                   ...
# 190         YEM           Yemen, Rep.
# 191         ZAF          South Africa
# 192         COD      Congo, Dem. Rep.
# 193         ZMB                Zambia
# 194         ZWE              Zimbabwe
#
# [195 rows x 2 columns]

# %%
df_numerical_data=df[['BirthRate', 'InternetUsers']]

# %%
df_categorical_data=df[['CountryName', 'CountryCode','IncomeGroup']]

# %%
df_numerical_data.head(1)
# Out:
#    BirthRate  InternetUsers
# 0     10.244           78.9

# %%
df_categorical_data.head(1)
# Out:
#   CountryName CountryCode  IncomeGroup
# 0       Aruba         ABW  High income

# %%
print(df_numerical_data.shape)
print(df_categorical_data.shape)
print(df.shape)
# Out:
# (195, 2)
# (195, 3)
# (195, 5)

# %%
print(df_numerical_data.columns)
print(df_categorical_data.columns)
# Out:
# Index(['BirthRate', 'InternetUsers'], dtype='object')
# Index(['CountryName', 'CountryCode', 'IncomeGroup'], dtype='object')

# %%
df[:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df[10:11]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 10  Azerbaijan         AZE       18.3           58.7  Upper middle income

# %%
df[0:100:20]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0        Aruba         ABW     10.244          78.90          High income
# 20     Belarus         BLR     12.500          54.17  Upper middle income
# 40  Costa Rica         CRI     15.022          45.96  Upper middle income
# 60       Gabon         GAB     30.555           9.20  Upper middle income
# 80       India         IND     20.291          15.10  Lower middle income

# %%
df[::5] #every 5th records
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244      78.900000
# 5                Argentina         ARG     17.716      59.900000
# 10              Azerbaijan         AZE     18.300      58.700000
# 15              Bangladesh         BGD     20.142       6.630000
# 20                 Belarus         BLR     12.500      54.170000
# 25                Barbados         BRB     12.188      73.000000
# 30                  Canada         CAN     10.900      85.800000
# 35                Cameroon         CMR     37.236       6.400000
# 40              Costa Rica         CRI     15.022      45.960000
# 45                 Germany         DEU      8.500      84.170000
# 50                 Ecuador         ECU     21.070      40.353684
# 55                Ethiopia         ETH     32.925       1.900000
# 60                   Gabon         GAB     30.555       9.200000
# ...

# %%
df[::-1] #reversing
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
df[::-5] #reversing 5th stesp
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 194                  Zimbabwe         ZWE     35.715        18.5000
# 189                     Samoa         WSM     26.172        15.3000
# 184             Venezuela, RB         VEN     19.842        54.9000
# 179                   Ukraine         UKR     11.100        41.0000
# 174       Trinidad and Tobago         TTO     14.590        63.8000
# 169                  Thailand         THA     11.041        28.9400
# 164                 Swaziland         SWZ     30.093        24.7000
# 159     Sao Tome and Principe         STP     34.537        23.0000
# 154              Sierra Leone         SLE     36.729         1.7000
# 149              Saudi Arabia         SAU     20.576        60.5000
# 144          French Polynesia         PYF     16.393        56.8000
# 139          Papua New Guinea         PNG     28.899         6.5000
# 134                      Oman         OMN     20.419        66.4500
# ...

# %%
df.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df.isna()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df_categorical_data.describe()
# Out:
#        CountryName CountryCode  IncomeGroup
# count          195         195          195
# unique         195         195            4
# top          Aruba         ABW  High income
# freq             1           1           67

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df1=df.copy()

# %%
df.columns=['a','b','c','d','e']

# %%
df
# Out:
#                         a    b       c     d                    e
# 0                   Aruba  ABW  10.244  78.9          High income
# 1             Afghanistan  AFG  35.253   5.9           Low income
# 2                  Angola  AGO  45.985  19.1  Upper middle income
# 3                 Albania  ALB  12.877  57.2  Upper middle income
# 4    United Arab Emirates  ARE  11.044  88.0          High income
# ..                    ...  ...     ...   ...                  ...
# 190           Yemen, Rep.  YEM  32.947  20.0  Lower middle income
# 191          South Africa  ZAF  20.850  46.5  Upper middle income
# 192      Congo, Dem. Rep.  COD  42.394   2.2           Low income
# 193                Zambia  ZMB  40.471  15.4  Lower middle income
# 194              Zimbabwe  ZWE  35.715  18.5           Low income
#
# [195 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df1.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df1['myCalc']=df1['BirthRate']*df1['InternetUsers']

# %%
df1
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup    myCalc
# 0            High income  808.2516
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 3    Upper middle income  736.5644
# ...

# %%
df1=df1.drop('myCalc',axis=1)

# %%
df1.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df1['InternetUsers']<2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
df[df1['InternetUsers']<2]
# Out:
#                 a    b       c    d                    e
# 11        Burundi  BDI  44.151  1.3           Low income
# 52        Eritrea  ERI  34.800  0.9           Low income
# 55       Ethiopia  ETH  32.925  1.9           Low income
# 64         Guinea  GIN  37.337  1.6           Low income
# 117       Myanmar  MMR  18.119  1.6  Lower middle income
# 127         Niger  NER  49.661  1.7           Low income
# 154  Sierra Leone  SLE  36.729  1.7           Low income
# 156       Somalia  SOM  43.891  1.5           Low income
# 172   Timor-Leste  TLS  35.755  1.1  Lower middle income

# %%
len(df[df1['InternetUsers']<2])
# Out:
# 9

# %%
len(df[df1['BirthRate']>40])
# Out:
# 12

# %%
df1[(df1['BirthRate']>40) & (df1['InternetUsers'] < 2)]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
df1[(df1.BirthRate>40) & (df1.InternetUsers < 2)]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
#27 may

df1=df.copy()

# %%
df1.columns=['CountryName','CountryCode',	'BirthRate',	'InternetUsers',	'IncomeGroup']

# %%
df1
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df1.IncomeGroup.nunique()
# Out:
# 4

# %%
df1[df1['IncomeGroup']=='High income']
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
# [67 rows x 5 columns]

# %%
import matplotlib.pyplot as plt #visulization
import seaborn as sns  #Statical/distribution visulization
# %matplotlib inline
plt.rcParams['figure.figsize'] =  (6,2) # reduce the graph size

import warnings
warnings.filterwarnings('ignore')

# %%
df1['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
vis1=sns.distplot(df1['InternetUsers']) #if this does not work--use plt.show()

# %%
plt.show()

# %%
vis2=sns.displot(df1['InternetUsers'])

# %%
vis2=sns.displot(df1['InternetUsers'],bins=15)

# %%
vis3=sns.boxplot(data=df1, x='IncomeGroup',y='BirthRate')

# %%
vis4=sns.lmplot(data=df1, x='InternetUsers',y='BirthRate')

# %%
vis4=sns.lmplot(data=df1, x='InternetUsers',y='BirthRate', fit_reg=False)

# %%
vis5=sns.lmplot(data=df1, x='InternetUsers',y='BirthRate', fit_reg=False,hue='IncomeGroup')

# %%
vis6=sns.lmplot(data=df1, x='InternetUsers',y='BirthRate', fit_reg=True,hue='IncomeGroup')
